# %% [markdown]
# <a href="https://colab.research.google.com/github/gmvarshini/Customer-Churn-Prediction-using-Deep-Learning-ANN/blob/main/Bank_Customer_Churn_Prediction_using_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from tensorflow.keras import regularizers
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score

# %%
data=pd.read_csv(r"/content/Churn_Modelling.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# # Data preprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
del data["CustomerId"]
del data["RowNumber"]

# %%
le=LabelEncoder()
data["Surname"]=le.fit_transform(data["Surname"])
data["Geography"]=le.fit_transform(data["Geography"])
data["Gender"]=le.fit_transform(data["Gender"])

# %%
data.head()
# Out:
#    Surname  CreditScore  Geography  Gender  Age  Tenure    Balance  \
# 0     1115          619          0       0   42       2       0.00
# 1     1177          608          2       0   41       1   83807.86
# 2     2040          502          0       0   42       8  159660.80
# 3      289          699          0       0   39       1       0.00
# 4     1822          850          2       0   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %% [markdown]
# # Data Visualization

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(data["Exited"])
# Out:
# <Axes: ylabel='count'>

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Surname'}>,
#         <Axes: title={'center': 'CreditScore'}>,
#         <Axes: title={'center': 'Geography'}>],
#        [<Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Tenure'}>],
#        [<Axes: title={'center': 'Balance'}>,
#         <Axes: title={'center': 'NumOfProducts'}>,
#         <Axes: title={'center': 'HasCrCard'}>],
#        [<Axes: title={'center': 'IsActiveMember'}>,
#         <Axes: title={'center': 'EstimatedSalary'}>,
#         <Axes: title={'center': 'Exited'}>]], dtype=object)

# %%
cmap=sns.diverging_palette(150,75,  s=40, l=65, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap=cmap,annot=True, square=True);

# %%
data.head()
# Out:
#    Surname  CreditScore  Geography  Gender  Age  Tenure    Balance  \
# 0     1115          619          0       0   42       2       0.00
# 1     1177          608          2       0   41       1   83807.86
# 2     2040          502          0       0   42       8  159660.80
# 3      289          699          0       0   39       1       0.00
# 4     1822          850          2       0   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %%
sns.kdeplot(data["Surname"],color='red')
# Out:
# <Axes: xlabel='Surname', ylabel='Density'>

# %%
sns.kdeplot(data["CreditScore"],color='blue')
# Out:
# <Axes: xlabel='CreditScore', ylabel='Density'>

# %%
sns.kdeplot(data["Balance"],color='red')
# Out:
# <Axes: xlabel='Balance', ylabel='Density'>

# %%
sns.kdeplot(data["EstimatedSalary"],color='blue')
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Density'>

# %%
sns.kdeplot(data["Exited"],color='red')
# Out:
# <Axes: xlabel='Exited', ylabel='Density'>

# %% [markdown]
# # Outlier detection

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
IQR
print("outlier Counter of the all features")
((data < (Q1 - 1.5 * IQR)) | (data> (Q3 + 1.5 * IQR))).sum()
# Out:
# outlier Counter of the all features
# Surname               0
# CreditScore          15
# Geography             0
# Gender                0
# Age                 359
# Tenure                0
# Balance               0
# NumOfProducts        60
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited             2037
# dtype: int64

# %%
for col in data.columns:
    if data[col].dtypes != 'object':
        q1 , q3 =data[col].quantile(0.25),data[col].quantile(0.75)
        iqr = q3 - q1
        ll = q1-1.5*iqr
        ul = q3 + 1.5*iqr
        data["CreditScore"] = np.where(data["CreditScore"]>ul,data["CreditScore"].mean(),np.where(data["CreditScore"]<ll,data["CreditScore"].mean(),data["CreditScore"]))  
        data["Age"] = np.where(data["Age"]>ul,data["Age"].mean(),np.where(data["Age"]<ll,data["Age"].mean(),data["Age"]))  
        data["NumOfProducts"] = np.where(data["NumOfProducts"]>ul,data["NumOfProducts"].mean(),np.where(data["NumOfProducts"]<ll,data["NumOfProducts"].mean(),data["NumOfProducts"]))

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
IQR
print("outlier Counter of the all features")
((data < (Q1 - 1.5 * IQR)) | (data> (Q3 + 1.5 * IQR))).sum()
# Out:
# outlier Counter of the all features
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited             2037
# dtype: int64

# %% [markdown]
# # Data imbalancing

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
S=RandomOverSampler()
x_data,y_data=S.fit_resample(x,y)
print(Counter(y_data))
# Out:
# Counter({1: 7963, 0: 7963})

# %% [markdown]
# # Data Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
d=mms.fit_transform(x_data)
d
# Out:
# array([[0.38041624, 0.538     , 0.        , ..., 1.        , 1.        ,
#         0.50673489],
#        [0.40156943, 0.516     , 1.        , ..., 0.        , 1.        ,
#         0.56270874],
#        [0.69600819, 0.304     , 0.        , ..., 1.        , 0.        ,
#         0.56965435],
#        ...,
#        [0.16444899, 0.452     , 0.        , ..., 0.        , 0.        ,
#         0.95520922],
#        [0.8287274 , 0.544     , 0.5       , ..., 1.        , 0.        ,
#         0.60207765],
#        [0.90276356, 0.558     , 0.5       , ..., 1.        , 1.        ,
#         0.32422176]])

# %% [markdown]
# # Data spliting and model fiting

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(d,y_data,random_state=250,test_size=0.25)

# %%
from keras import callbacks
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# %%
import tensorflow as tf
ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units=25, activation='relu'))
ann.add(tf.keras.layers.Dense(units=8, activation='relu'))
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
ann.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
history = ann.fit(x_train,y_train,batch_size=20,epochs=100,validation_split=0.25)
# Out:
# Epoch 1/100
# 448/448 [==============================] - 2s 3ms/step - loss: 0.6602 - accuracy: 0.6136 - val_loss: 0.6163 - val_accuracy: 0.6644
# Epoch 2/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.6012 - accuracy: 0.6792 - val_loss: 0.5811 - val_accuracy: 0.6956
# Epoch 3/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.5701 - accuracy: 0.7029 - val_loss: 0.5592 - val_accuracy: 0.7083
# Epoch 4/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.5473 - accuracy: 0.7218 - val_loss: 0.5378 - val_accuracy: 0.7237
# Epoch 5/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.5289 - accuracy: 0.7392 - val_loss: 0.5225 - val_accuracy: 0.7334
# Epoch 6/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.5137 - accuracy: 0.7489 - val_loss: 0.5145 - val_accuracy: 0.7401
# Epoch 7/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.5019 - accuracy: 0.7569 - val_loss: 0.5100 - val_accuracy: 0.7448
# Epoch 8/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4938 - accuracy: 0.7614 - val_loss: 0.4941 - val_accuracy: 0.7528
# Epoch 9/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4875 - accuracy: 0.7647 - val_loss: 0.4882 - val_accuracy: 0.7595
# Epoch 10/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4812 - accuracy: 0.7728 - val_loss: 0.4854 - val_accuracy: 0.7632
# Epoch 11/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4772 - accuracy: 0.7714 - val_loss: 0.4800 - val_accuracy: 0.7642
# Epoch 12/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4730 - accuracy: 0.7739 - val_loss: 0.4814 - val_accuracy: 0.7636
# Epoch 13/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4694 - accuracy: 0.7712 - val_loss: 0.4759 - val_accuracy: 0.7669
# Epoch 14/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4672 - accuracy: 0.7783 - val_loss: 0.4796 - val_accuracy: 0.7666
# Epoch 15/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4648 - accuracy: 0.7770 - val_loss: 0.4801 - val_accuracy: 0.7652
# Epoch 16/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4615 - accuracy: 0.7777 - val_loss: 0.4827 - val_accuracy: 0.7676
# Epoch 17/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4608 - accuracy: 0.7767 - val_loss: 0.4742 - val_accuracy: 0.7639
# Epoch 18/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4573 - accuracy: 0.7791 - val_loss: 0.4697 - val_accuracy: 0.7669
# Epoch 19/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4574 - accuracy: 0.7812 - val_loss: 0.4693 - val_accuracy: 0.7709
# Epoch 20/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4562 - accuracy: 0.7818 - val_loss: 0.4668 - val_accuracy: 0.7723
# Epoch 21/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4548 - accuracy: 0.7797 - val_loss: 0.4690 - val_accuracy: 0.7703
# Epoch 22/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4520 - accuracy: 0.7823 - val_loss: 0.4829 - val_accuracy: 0.7642
# Epoch 23/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4515 - accuracy: 0.7801 - val_loss: 0.4685 - val_accuracy: 0.7679
# Epoch 24/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4493 - accuracy: 0.7825 - val_loss: 0.4663 - val_accuracy: 0.7749
# Epoch 25/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4483 - accuracy: 0.7852 - val_loss: 0.4663 - val_accuracy: 0.7733
# Epoch 26/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4472 - accuracy: 0.7819 - val_loss: 0.4645 - val_accuracy: 0.7739
# Epoch 27/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4463 - accuracy: 0.7834 - val_loss: 0.4632 - val_accuracy: 0.7760
# Epoch 28/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4445 - accuracy: 0.7834 - val_loss: 0.4719 - val_accuracy: 0.7739
# Epoch 29/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4431 - accuracy: 0.7857 - val_loss: 0.4606 - val_accuracy: 0.7770
# Epoch 30/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4425 - accuracy: 0.7866 - val_loss: 0.4617 - val_accuracy: 0.7760
# Epoch 31/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4420 - accuracy: 0.7864 - val_loss: 0.4575 - val_accuracy: 0.7773
# Epoch 32/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4407 - accuracy: 0.7851 - val_loss: 0.4732 - val_accuracy: 0.7666
# Epoch 33/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4402 - accuracy: 0.7883 - val_loss: 0.4568 - val_accuracy: 0.7766
# Epoch 34/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4414 - accuracy: 0.7858 - val_loss: 0.4678 - val_accuracy: 0.7770
# Epoch 35/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4387 - accuracy: 0.7899 - val_loss: 0.4586 - val_accuracy: 0.7776
# Epoch 36/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4377 - accuracy: 0.7867 - val_loss: 0.4574 - val_accuracy: 0.7766
# Epoch 37/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4361 - accuracy: 0.7912 - val_loss: 0.4553 - val_accuracy: 0.7786
# Epoch 38/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4358 - accuracy: 0.7889 - val_loss: 0.4572 - val_accuracy: 0.7810
# Epoch 39/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4358 - accuracy: 0.7863 - val_loss: 0.4569 - val_accuracy: 0.7746
# Epoch 40/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4355 - accuracy: 0.7885 - val_loss: 0.4565 - val_accuracy: 0.7837
# Epoch 41/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4332 - accuracy: 0.7918 - val_loss: 0.4531 - val_accuracy: 0.7736
# Epoch 42/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4326 - accuracy: 0.7906 - val_loss: 0.4559 - val_accuracy: 0.7786
# Epoch 43/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4324 - accuracy: 0.7911 - val_loss: 0.4586 - val_accuracy: 0.7793
# Epoch 44/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4331 - accuracy: 0.7892 - val_loss: 0.4549 - val_accuracy: 0.7806
# Epoch 45/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4316 - accuracy: 0.7929 - val_loss: 0.4523 - val_accuracy: 0.7823
# Epoch 46/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4312 - accuracy: 0.7909 - val_loss: 0.4491 - val_accuracy: 0.7793
# Epoch 47/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4298 - accuracy: 0.7930 - val_loss: 0.4519 - val_accuracy: 0.7793
# Epoch 48/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4298 - accuracy: 0.7930 - val_loss: 0.4531 - val_accuracy: 0.7773
# Epoch 49/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4289 - accuracy: 0.7934 - val_loss: 0.4636 - val_accuracy: 0.7749
# Epoch 50/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4296 - accuracy: 0.7925 - val_loss: 0.4531 - val_accuracy: 0.7840
# Epoch 51/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4277 - accuracy: 0.7921 - val_loss: 0.4487 - val_accuracy: 0.7816
# Epoch 52/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4283 - accuracy: 0.7935 - val_loss: 0.4505 - val_accuracy: 0.7803
# Epoch 53/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4268 - accuracy: 0.7934 - val_loss: 0.4643 - val_accuracy: 0.7646
# Epoch 54/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4268 - accuracy: 0.7956 - val_loss: 0.4455 - val_accuracy: 0.7810
# Epoch 55/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4267 - accuracy: 0.7958 - val_loss: 0.4526 - val_accuracy: 0.7867
# Epoch 56/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4260 - accuracy: 0.7943 - val_loss: 0.4498 - val_accuracy: 0.7803
# Epoch 57/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4266 - accuracy: 0.7935 - val_loss: 0.4474 - val_accuracy: 0.7833
# Epoch 58/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4250 - accuracy: 0.7996 - val_loss: 0.4451 - val_accuracy: 0.7843
# Epoch 59/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4242 - accuracy: 0.7955 - val_loss: 0.4429 - val_accuracy: 0.7833
# Epoch 60/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4232 - accuracy: 0.7971 - val_loss: 0.4501 - val_accuracy: 0.7793
# Epoch 61/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4236 - accuracy: 0.7955 - val_loss: 0.4470 - val_accuracy: 0.7823
# Epoch 62/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4237 - accuracy: 0.7928 - val_loss: 0.4571 - val_accuracy: 0.7796
# Epoch 63/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4229 - accuracy: 0.7954 - val_loss: 0.4482 - val_accuracy: 0.7873
# Epoch 64/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4222 - accuracy: 0.7965 - val_loss: 0.4553 - val_accuracy: 0.7760
# Epoch 65/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4232 - accuracy: 0.7986 - val_loss: 0.4494 - val_accuracy: 0.7820
# Epoch 66/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4217 - accuracy: 0.7963 - val_loss: 0.4501 - val_accuracy: 0.7847
# Epoch 67/100
# 448/448 [==============================] - 2s 4ms/step - loss: 0.4210 - accuracy: 0.7991 - val_loss: 0.4530 - val_accuracy: 0.7813
# Epoch 68/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4220 - accuracy: 0.7988 - val_loss: 0.4518 - val_accuracy: 0.7780
# Epoch 69/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4209 - accuracy: 0.8010 - val_loss: 0.4479 - val_accuracy: 0.7823
# Epoch 70/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4231 - accuracy: 0.7974 - val_loss: 0.4489 - val_accuracy: 0.7780
# Epoch 71/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4223 - accuracy: 0.7981 - val_loss: 0.4484 - val_accuracy: 0.7813
# Epoch 72/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4213 - accuracy: 0.7981 - val_loss: 0.4530 - val_accuracy: 0.7853
# Epoch 73/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4196 - accuracy: 0.7983 - val_loss: 0.4449 - val_accuracy: 0.7873
# Epoch 74/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4206 - accuracy: 0.7979 - val_loss: 0.4431 - val_accuracy: 0.7850
# Epoch 75/100
# 448/448 [==============================] - 2s 4ms/step - loss: 0.4190 - accuracy: 0.7986 - val_loss: 0.4399 - val_accuracy: 0.7863
# Epoch 76/100
# 448/448 [==============================] - 3s 6ms/step - loss: 0.4209 - accuracy: 0.7994 - val_loss: 0.4533 - val_accuracy: 0.7786
# Epoch 77/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4203 - accuracy: 0.8000 - val_loss: 0.4471 - val_accuracy: 0.7790
# Epoch 78/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4198 - accuracy: 0.7995 - val_loss: 0.4545 - val_accuracy: 0.7823
# Epoch 79/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4178 - accuracy: 0.8006 - val_loss: 0.4524 - val_accuracy: 0.7749
# Epoch 80/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4180 - accuracy: 0.8007 - val_loss: 0.4462 - val_accuracy: 0.7870
# Epoch 81/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4192 - accuracy: 0.7996 - val_loss: 0.4445 - val_accuracy: 0.7897
# Epoch 82/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4180 - accuracy: 0.7996 - val_loss: 0.4451 - val_accuracy: 0.7883
# Epoch 83/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4178 - accuracy: 0.8004 - val_loss: 0.4421 - val_accuracy: 0.7870
# Epoch 84/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4196 - accuracy: 0.7976 - val_loss: 0.4462 - val_accuracy: 0.7860
# Epoch 85/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4175 - accuracy: 0.7991 - val_loss: 0.4435 - val_accuracy: 0.7840
# Epoch 86/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4176 - accuracy: 0.8007 - val_loss: 0.4405 - val_accuracy: 0.7857
# Epoch 87/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4178 - accuracy: 0.8029 - val_loss: 0.4439 - val_accuracy: 0.7853
# Epoch 88/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4157 - accuracy: 0.7992 - val_loss: 0.4428 - val_accuracy: 0.7877
# Epoch 89/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4168 - accuracy: 0.7992 - val_loss: 0.4423 - val_accuracy: 0.7853
# Epoch 90/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4166 - accuracy: 0.8025 - val_loss: 0.4440 - val_accuracy: 0.7847
# Epoch 91/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4151 - accuracy: 0.8001 - val_loss: 0.4522 - val_accuracy: 0.7756
# Epoch 92/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4176 - accuracy: 0.8015 - val_loss: 0.4446 - val_accuracy: 0.7870
# Epoch 93/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4145 - accuracy: 0.8032 - val_loss: 0.4568 - val_accuracy: 0.7743
# Epoch 94/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4169 - accuracy: 0.7981 - val_loss: 0.4438 - val_accuracy: 0.7816
# Epoch 95/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4163 - accuracy: 0.8001 - val_loss: 0.4451 - val_accuracy: 0.7827
# Epoch 96/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4149 - accuracy: 0.8011 - val_loss: 0.4432 - val_accuracy: 0.7914
# Epoch 97/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4155 - accuracy: 0.7993 - val_loss: 0.4429 - val_accuracy: 0.7837
# Epoch 98/100
# 448/448 [==============================] - 1s 2ms/step - loss: 0.4142 - accuracy: 0.8049 - val_loss: 0.4468 - val_accuracy: 0.7847
# Epoch 99/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4148 - accuracy: 0.8002 - val_loss: 0.4457 - val_accuracy: 0.7813
# Epoch 100/100
# 448/448 [==============================] - 1s 3ms/step - loss: 0.4148 - accuracy: 0.8024 - val_loss: 0.4475 - val_accuracy: 0.7793

# %%
y_pred = ann.predict(x_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
print(y_pred)
# Out:
# 125/125 [==============================] - 0s 1ms/step
# [[ True]
#  [False]
#  [ True]
#  ...
#  [False]
#  [ True]
#  [False]]

# %%
Pred=[]
for s in y_pred:
    if s==False:
        a=0
        Pred.append(a)
    else: 
        b=1
        Pred.append(b)

# %%
y_test
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
Prediction=pd.DataFrame({"Actual":y_test,"Predicted":Pred})
Prediction
# Out:
#       Actual  Predicted
# 0          1          1
# 1          0          0
# 2          1          1
# 3          1          1
# 4          1          1
# ...      ...        ...
# 3977       1          1
# 3978       0          1
# 3979       0          0
# 3980       1          1
# 3981       0          0
#
# [3982 rows x 2 columns]

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
import matplotlib.pyplot as plt
cmap1 = sns.diverging_palette(751,75,  s=40, l=65, n=6)
plt.subplots(figsize=(4,2))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
cf_matrix
# Out:
# array([[1639,  345],
#        [ 516, 1482]])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# # Checking accuracy

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.79      1984
#            1       0.81      0.74      0.77      1998
#
#     accuracy                           0.78      3982
#    macro avg       0.79      0.78      0.78      3982
# weighted avg       0.79      0.78      0.78      3982

# %% [markdown]
# # The model gives 78% accuracy by using adam optimizer
